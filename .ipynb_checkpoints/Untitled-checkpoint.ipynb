# %%
import pandas as pd
import csv
import numpy as np
from nltk.tokenize import word_tokenize, sent_tokenize
import spacy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-2d08fd95cf38> in <module>
#       3 import numpy as np
#       4 from nltk.tokenize import word_tokenize, sent_tokenize
# ----> 5 import spacy
#
# ImportError: No module named 'spacy'

# %%
df = pd.read_csv('v4_atomic_all_agg.csv')

# %%
counter = 0
for event in list(df['event']):
    if('PersonY' not in event):
        counter += 1

# %%
df.iloc[5]['oEffect']

# %%
df.groupby(['prefix']).count().sort_values('event')
# Out:
#                          event  oEffect  oReact  oWant  xAttr  xEffect  \
# prefix
# ["10", "years"]              1        1       1      1      1        1
# ["plants", "seed"]           1        1       1      1      1        1
# ["plants", "yard"]           1        1       1      1      1        1
# ["playing", "ball"]          1        1       1      1      1        1
# ["playing", "baseball"]      1        1       1      1      1        1
# ["playing", "catch"]         1        1       1      1      1        1
# ["playing", "hide"]          1        1       1      1      1        1
# ["playing", "monopoly"]      1        1       1      1      1        1
# ["playing", "outside"]       1        1       1      1      1        1
# ["playing", "poker"]         1        1       1      1      1        1
# ["playing", "snow"]          1        1       1      1      1        1
# ["playing", "soccer"]        1        1       1      1      1        1
# ["playing", "tennis"]        1        1       1      1      1        1
# ["playing", "yard"]          1        1       1      1      1        1
# ["plays", "according"]       1        1       1      1      1        1
# ["plays", "alone"]           1        1       1      1      1        1
# ["plays", "angles"]          1        1       1      1      1        1
# ["plays", "anymore"]         1        1       1      1      1        1
# ["plays", "arcade"]          1        1       1      1      1        1
# ["plays", "badminton"]       1        1       1      1      1        1
# ["plays", "ball"]            1        1       1      1      1        1
# ["plays", "banjo"]           1        1       1      1      1        1
# ["plants", "flowers"]        1        1       1      1      1        1
# ["plants", "backyard"]       1        1       1      1      1        1
# ["plants", "apple"]          1        1       1      1      1        1
# ["plans", "party"]           1        1       1      1      1        1
# ["places", "first"]          1        1       1      1      1        1
# ["places", "flowers"]        1        1       1      1      1        1
# ["places", "footing"]        1        1       1      1      1        1
# ["places", "hand"]           1        1       1      1      1        1
# ...                        ...      ...     ...    ...    ...      ...
# ["moves", "new"]            14       14      14     14     14       14
# ["holds", "hand"]           14       14      14     14     14       14
# ["wants", "learn"]          14       14      14     14     14       14
# ["gets", "money"]           14       14      14     14     14       14
# ["walks", "home"]           14       14      14     14     14       14
# ["invites", "friends"]      15       15      15     15     15       15
# ["feels", "like"]           16       16      16     16     16       16
# ["knows", "well"]           16       16      16     16     16       16
# ["falls", "asleep"]         17       17      17     17     17       17
# ["takes", "dog"]            17       17      17     17     17       17
# ["spends", "time"]          17       17      17     17     17       17
# ["learns", "play"]          18       18      18     18     18       18
# ["needs", "new"]            18       18      18     18     18       18
# ["can", "find"]             18       18      18     18     18       18
# ["wants", "new"]            19       19      19     19     19       19
# ["comes", "back"]           19       19      19     19     19       19
# ["looks", "like"]           19       19      19     19     19       19
# ["comes", "home"]           19       19      19     19     19       19
# ["takes", "care"]           20       20      20     20     20       20
# ["depends", "upon"]         21       21      21     21     21       21
# ["drives", "home"]          22       22      22     22     22       22
# ["gets", "back"]            22       22      22     22     22       22
# ["takes", "part"]           22       22      22     22     22       22
# ["works", "hard"]           25       25      25     25     25       25
# ["goes", "back"]            31       31      31     31     31       31
# ["wants", "go"]             31       31      31     31     31       31
# ["goes", "home"]            31       31      31     31     31       31
# ["decides", "go"]           32       32      32     32     32       32
# ["gets", "new"]             34       34      34     34     34       34
# ["buys", "new"]             77       77      77     77     77       77
#
#                          xIntent  xNeed  xReact  xWant  split
# prefix
# ["10", "years"]                1      1       1      1      1
# ["plants", "seed"]             1      1       1      1      1
# ["plants", "yard"]             1      1       1      1      1
# ["playing", "ball"]            1      1       1      1      1
# ["playing", "baseball"]        1      1       1      1      1
# ["playing", "catch"]           1      1       1      1      1
# ["playing", "hide"]            1      1       1      1      1
# ["playing", "monopoly"]        1      1       1      1      1
# ["playing", "outside"]         1      1       1      1      1
# ["playing", "poker"]           1      1       1      1      1
# ["playing", "snow"]            1      1       1      1      1
# ["playing", "soccer"]          1      1       1      1      1
# ["playing", "tennis"]          1      1       1      1      1
# ["playing", "yard"]            1      1       1      1      1
# ["plays", "according"]         1      1       1      1      1
# ["plays", "alone"]             1      1       1      1      1
# ["plays", "angles"]            1      1       1      1      1
# ["plays", "anymore"]           1      1       1      1      1
# ["plays", "arcade"]            1      1       1      1      1
# ["plays", "badminton"]         1      1       1      1      1
# ["plays", "ball"]              1      1       1      1      1
# ["plays", "banjo"]             1      1       1      1      1
# ["plants", "flowers"]          1      1       1      1      1
# ["plants", "backyard"]         1      1       1      1      1
# ["plants", "apple"]            1      1       1      1      1
# ["plans", "party"]             1      1       1      1      1
# ["places", "first"]            1      1       1      1      1
# ["places", "flowers"]          1      1       1      1      1
# ["places", "footing"]          1      1       1      1      1
# ["places", "hand"]             1      1       1      1      1
# ...                          ...    ...     ...    ...    ...
# ["moves", "new"]              14     14      14     14     14
# ["holds", "hand"]             14     14      14     14     14
# ["wants", "learn"]            14     14      14     14     14
# ["gets", "money"]             14     14      14     14     14
# ["walks", "home"]             14     14      14     14     14
# ["invites", "friends"]        15     15      15     15     15
# ["feels", "like"]             16     16      16     16     16
# ["knows", "well"]             16     16      16     16     16
# ["falls", "asleep"]           17     17      17     17     17
# ["takes", "dog"]              17     17      17     17     17
# ["spends", "time"]            17     17      17     17     17
# ["learns", "play"]            18     18      18     18     18
# ["needs", "new"]              18     18      18     18     18
# ["can", "find"]               18     18      18     18     18
# ["wants", "new"]              19     19      19     19     19
# ["comes", "back"]             19     19      19     19     19
# ["looks", "like"]             19     19      19     19     19
# ["comes", "home"]             19     19      19     19     19
# ["takes", "care"]             20     20      20     20     20
# ["depends", "upon"]           21     21      21     21     21
# ["drives", "home"]            22     22      22     22     22
# ["gets", "back"]              22     22      22     22     22
# ["takes", "part"]             22     22      22     22     22
# ["works", "hard"]             25     25      25     25     25
# ["goes", "back"]              31     31      31     31     31
# ["wants", "go"]               31     31      31     31     31
# ["goes", "home"]              31     31      31     31     31
# ["decides", "go"]             32     32      32     32     32
# ["gets", "new"]               34     34      34     34     34
# ["buys", "new"]               77     77      77     77     77
#
# [15861 rows x 11 columns]

# %%
df.loc[df['prefix'] == '["buys", "new"]']
# Out:
#                                          event  \
# 1778          PersonX buys PersonX's new shoes
# 1789           PersonX buys PersonY a new bike
# 1790            PersonX buys PersonY a new car
# 1791            PersonX buys PersonY a new one
# 1792           PersonX buys PersonY a new pair
# 1796            PersonX buys PersonY new shoes
# 1813                PersonX buys ___ a new one
# 1852  PersonX buys ___ for the new school year
# 1924                PersonX buys a new battery
# 1925                   PersonX buys a new bike
# 1926                   PersonX buys a new boat
# 1927                   PersonX buys a new book
# 1928                  PersonX buys a new brush
# 1929                 PersonX buys a new camera
# 1930                    PersonX buys a new car
# 1931             PersonX buys a new cell phone
# 1932                  PersonX buys a new chair
# 1933                PersonX buys a new charger
# 1934               PersonX buys a new computer
# 1935                  PersonX buys a new couch
# 1936                    PersonX buys a new dog
# 1937                  PersonX buys a new dress
# 1938                    PersonX buys a new fan
# 1939                   PersonX buys a new fish
# 1940                   PersonX buys a new game
# 1941                 PersonX buys a new guitar
# 1942                    PersonX buys a new gun
# 1943                    PersonX buys a new hat
# 1944                   PersonX buys a new home
# 1945                  PersonX buys a new house
# ...                                        ...
# 1963                  PersonX buys a new purse
# 1964                PersonX buys a new racquet
# 1965                  PersonX buys a new shirt
# 1966                   PersonX buys a new sofa
# 1967                   PersonX buys a new suit
# 1968                PersonX buys a new sweater
# 1969             PersonX buys a new television
# 1970                   PersonX buys a new tent
# 1971                   PersonX buys a new tire
# 1972                PersonX buys a new toaster
# 1973                    PersonX buys a new toy
# 1974                  PersonX buys a new truck
# 1975                     PersonX buys a new tv
# 1976             PersonX buys a new video game
# 1977                 PersonX buys a new wallet
# 1978               PersonX buys a new wardrobe
# 1979                  PersonX buys a new watch
# 2055                  PersonX buys new clothes
# 2056                PersonX buys new furniture
# 2057                  PersonX buys new glasses
# 2058               PersonX buys new headphones
# 2059                     PersonX buys new ones
# 2060                    PersonX buys new pants
# 2061                   PersonX buys new sheets
# 2062                    PersonX buys new shoes
# 2063                    PersonX buys new socks
# 2080             PersonX buys some new clothes
# 2081                PersonX buys some new ones
# 2082               PersonX buys some new shoes
# 2108                 PersonX buys the new game
#
#                                                 oEffect  \
# 1778                           ["none", "none", "none"]
# 1789  ["none", "smiles", "getse around faster", "is ...
# 1790  ["look at PersonX's face to see their reaction...
# 1791  ["Becomes pleased, smiles", "Amasses new item"...
# 1792  ["smiles", "cries", "Opens the gift", "Buys a ...
# 1796              ["wears new shoes", "thanks someone"]
# 1813  ["Person is given gift", "Person thanks PersonX"]
# 1852          ["none", "Gets paid", "Receives payment"]
# 1924                           ["none", "none", "none"]
# 1925                           ["none", "none", "none"]
# 1926  ["someone no longer owns a boat", "someone sol...
# 1927                           ["none", "none", "none"]
# 1928                           ["none", "none", "none"]
# 1929                                   ["none", "none"]
# 1930  ["none", "Car seller gains money", "Car seller...
# 1931                                   ["none", "none"]
# 1932                                   ["none", "none"]
# 1933                           ["none", "none", "none"]
# 1934                           ["none", "none", "none"]
# 1935                           ["none", "none", "none"]
# 1936                                           ["none"]
# 1937                                   ["none", "none"]
# 1938                                   ["none", "none"]
# 1939                           ["none", "none", "none"]
# 1940                                   ["none", "none"]
# 1941                 ["investment", "purchase", "none"]
# 1942                                           ["none"]
# 1943                 ["none", "none", "scold", "fight"]
# 1944                           ["none", "none", "none"]
# 1945                           ["none", "none", "none"]
# ...                                                 ...
# 1963                           ["none", "none", "none"]
# 1964                                   ["none", "none"]
# 1965                           ["none", "none", "none"]
# 1966  ["Someone must deliver sofa.", "Salesperson ge...
# 1967                                   ["none", "none"]
# 1968                                   ["none", "none"]
# 1969                           ["none", "none", "none"]
# 1970  ["Can go camping with PersonX", "Has to buy ot...
# 1971  ["none", "tire dealership has more money", "ti...
# 1972                                   ["none", "none"]
# 1973                                   ["none", "none"]
# 1974        ["none", "gets paid", "gives keys", "none"]
# 1975                                   ["none", "none"]
# 1976                           ["none", "none", "none"]
# 1977  ["none", "accept payment for wallet.", "ring u...
# 1978                           ["none", "none", "none"]
# 1979                           ["none", "none", "none"]
# 2055                                           ["none"]
# 2056                           ["none", "none", "none"]
# 2057  ["receive gratitude for compliment", "no effec...
# 2058                                   ["none", "none"]
# 2059                                   ["none", "none"]
# 2060                                   ["none", "none"]
# 2061                                   ["none", "none"]
# 2062                                           ["none"]
# 2063  ["gains money", "has fewer socks to sell", "no...
# 2080                           ["none", "none", "none"]
# 2081                                           ["none"]
# 2082   ["none", "Compliments X", "Buys the same shoes"]
# 2108                           ["none", "none", "none"]
#
#                                                  oReact  \
# 1778                                   ["none", "none"]
# 1789  ["loved and happy.", "happy", "satisfied", "th...
# 1790                           ["grateful", "thankful"]
# 1791          ["thankful", "needy", "poor", "grateful"]
# 1792                     ["good for having a new pair"]
# 1796  ["special", "rewarded", "grateful", "surprised...
# 1813  ["surprised because they wasn't expecting a gi...
# 1852           ["none", "happy to do business", "none"]
# 1924                           ["none", "none", "none"]
# 1925                                           ["none"]
# 1926                                   ["none", "none"]
# 1927                                   ["none", "none"]
# 1928                           ["none", "none", "none"]
# 1929                                   ["none", "none"]
# 1930  ["none", "proud to have sold the car to x", "e...
# 1931                                   ["none", "none"]
# 1932                           ["none", "none", "none"]
# 1933                                   ["none", "none"]
# 1934                           ["none", "none", "none"]
# 1935                                   ["none", "none"]
# 1936                                   ["none", "none"]
# 1937                           ["none", "none", "none"]
# 1938                           ["none", "none", "none"]
# 1939      ["happy to have a new owner", "none", "none"]
# 1940                           ["none", "none", "none"]
# 1941                           ["none", "none", "none"]
# 1942                                           ["none"]
# 1943                                   ["none", "none"]
# 1944                          ["happy", "glad", "none"]
# 1945                                   ["none", "none"]
# ...                                                 ...
# 1963                                   ["none", "none"]
# 1964                           ["none", "none", "none"]
# 1965                                   ["none", "none"]
# 1966           ["none", "none", "happy", "comfortable"]
# 1967                                   ["none", "none"]
# 1968                                   ["none", "none"]
# 1969     ["excited they get to watch a new tv", "none"]
# 1970                              ["proud of person x"]
# 1971                                   ["none", "none"]
# 1972                         ["happy.", "none", "none"]
# 1973                           ["none", "none", "none"]
# 1974                                   ["none", "none"]
# 1975                                   ["none", "none"]
# 1976                           ["none", "none", "none"]
# 1977                           ["none", "none", "none"]
# 1978                                   ["none", "none"]
# 1979                           ["none", "none", "none"]
# 2055                           ["none", "none", "none"]
# 2056                           ["none", "none", "none"]
# 2057                                   ["none", "none"]
# 2058                           ["none", "none", "none"]
# 2059                                   ["none", "none"]
# 2060                           ["none", "none", "none"]
# 2061            ["none", "satisfied", "also refreshed"]
# 2062                           ["none", "none", "none"]
# 2063                           ["none", "none", "none"]
# 2080                                   ["none", "none"]
# 2081                                   ["none", "none"]
# 2082                           ["none", "none", "none"]
# 2108                         ["happy.", "none", "none"]
#
#                                                   oWant  \
# 1778                                           ["none"]
# 1789  ["to appreciate him", "to celebrate the event"...
# 1790  ["to thank him", "to express his gratitude", "...
# 1791  ["to thank PersonX", "to hug PersonX", "to acc...
# 1792  ["Buy something for PersonX", "Wear the pair",...
# 1796  ["to thank x", "to wear the shoes", "count mon...
# 1813  ["accept the new gift", "thank Person X", "to ...
# 1852                           ["none", "none", "none"]
# 1924                                           ["none"]
# 1925                                   ["none", "none"]
# 1926  ["to help PersonX bring the boat", "to thank P...
# 1927                                   ["none", "none"]
# 1928                           ["none", "none", "none"]
# 1929                           ["none", "none", "none"]
# 1930  ["none", "none", "collect percentage of sales"...
# 1931                                   ["none", "none"]
# 1932                           ["none", "none", "none"]
# 1933  ["to serve the next customer", "to restock cha...
# 1934                           ["none", "none", "none"]
# 1935                                   ["none", "none"]
# 1936                   ["none", "none", "none", "none"]
# 1937                           ["none", "none", "none"]
# 1938  ["none", "to stay cool", "to thank them for ge...
# 1939                           ["none", "none", "none"]
# 1940  ["none", "none", "play game with person x", "s...
# 1941                                   ["none", "none"]
# 1942  ["to make money", "to sell an gun", "none", "n...
# 1943                           ["none", "none", "none"]
# 1944  ["none", "sign deal", "collect money", "use th...
# 1945                                   ["none", "none"]
# ...                                                 ...
# 1963                                   ["none", "none"]
# 1964  ["plays the game with them", "admires the rack...
# 1965                           ["none", "none", "none"]
# 1966  ["none", "to help PersonX bring the sofa back"...
# 1967                                   ["none", "none"]
# 1968  ["none", "none", "put sweater in bag for Perso...
# 1969                           ["none", "none", "none"]
# 1970                                           ["none"]
# 1971     ["to get paid", "to complete the job", "none"]
# 1972                           ["none", "none", "none"]
# 1973  ["none", "none", "none", "jump for joy", "than...
# 1974                           ["none", "none", "none"]
# 1975  ["none", "to deliver the truck", "to thank Per...
# 1976                           ["none", "none", "none"]
# 1977                           ["none", "none", "none"]
# 1978                           ["none", "none", "none"]
# 1979                           ["none", "none", "none"]
# 2055                           ["none", "none", "none"]
# 2056  ["to go home at the end of the day after makin...
# 2057                           ["none", "none", "none"]
# 2058                                   ["none", "none"]
# 2059                           ["none", "none", "none"]
# 2060  ["none", "to buy something for themself", "to ...
# 2061                                   ["none", "none"]
# 2062                           ["none", "none", "none"]
# 2063  ["none", "to thank PersonX for coming", "to se...
# 2080  ["to thank person x for his patronage", "say g...
# 2081                                   ["none", "none"]
# 2082  ["none", "none", "to help the next customer.",...
# 2108                           ["none", "none", "none"]
#
#                                                   xAttr  \
# 1778  ["eager", "fashionable", "proud", "considerate...
# 1789  ["generous", "charitable", "generous", "charit...
# 1790      ["generous", "happy", "caring", "supportive"]
# 1791  ["thoughtful", "warm", "Generous", "Loving", "...
# 1792  ["generous", "kind", "caring", "thoughtful", "...
# 1796  ["caring", "rich", "kind", "giving", "wealthy"...
# 1813        ["rich", "finished", "considerate", "kind"]
# 1852             ["prepared", "eager", "rich", "smart"]
# 1924  ["determined", "excited", "thrifty", "resource...
# 1925  ["athletic", "acquisitive", "Young", "Venturin...
# 1926            ["moneyed", "rich", "hopeful", "happy"]
# 1927  ["decisive", "intellectual", "literate", "educ...
# 1928  ["conscientious", "fashionable", "competent", ...
# 1929        ["content", "happy", "wealthy", "affluent"]
# 1930     ["responsible", "diligent", "rich", "wealthy"]
# 1931       ["wealthy", "proud", "excited", "expecting"]
# 1932  ["practical", "utilitarian", "thoughtful", "cu...
# 1933  ["Prepared", "Good", "thrifty", "rich", "relie...
# 1934   ["savvy", "not frugal", "tecnological", "smart"]
# 1935  ["Comfortable", "Cozy", "needful", "materialis...
# 1936  ["alone", "animal lover", "happy", "excited", ...
# 1937  ["happy", "fashionable", "in a good mood", "de...
# 1938  ["Wealthy", "Rich", "moving", "at a yardsale",...
# 1939  ["excitable", "hopeful", "interested", "acquis...
# 1940  ["friendly", "competitive", "impulsive", "fun ...
# 1941    ["capable", "interested", "excited", "musical"]
# 1942  ["violent", "crazy", "happy", "satisfied", "ho...
# 1943      ["elderly", "delighted", "wealthy", "trendy"]
# 1944  ["excited", "happy", "responsible", "mature", ...
# 1945  ["indulgent", "capable", "creditworthy", "well...
# ...                                                 ...
# 1963  ["materialistic", "rich", "trendy", "shopping"...
# 1964           ["sporty", "hobbyist", "rich", "sporty"]
# 1965  ["wasteful", "stylish", "decisive", "trendy", ...
# 1966  ["remodeling", "decorating", "responsible", "p...
# 1967  ["indulgent", "financially secure", "refined",...
# 1968  ["capable", "in need", "rich", "health-conscio...
# 1969  ["interested", "fun", "happy", "rich", "rich",...
# 1970  ["free", "self-reliant", "adventurous", "outdo...
# 1971  ["concerned", "capable", "independent", "caref...
# 1972  ["decisive", "responsible", "capable", "motiva...
# 1973  ["youthful", "playful", "playful", "rich", "sp...
# 1974  ["Rich", "On track", "broke", "productive", "r...
# 1975  ["happy", "relaxed", "bored", "entertained", "...
# 1976  ["curious", "bored", "irresponsible", "addicte...
# 1977  ["rich", "fashionable", "indulgent", "careful"...
# 1978  ["materialistic", "wealthy", "trendy", "fashio...
# 1979  ["fantastic", "attractive", "wealthy", "rich",...
# 2055          ["thirfty", "happy", "rich", "confident"]
# 2056             ["rich", "wealthy", "wealthy", "rich"]
# 2057     ["hopeful", "far sighted", "done", "finished"]
# 2058  ["desirous", "lustful", "wealthy", "luxurious"...
# 2059    ["grateful", "relieved", "prepared", "capable"]
# 2060  ["fashionable", "dressy", "attractive", "gorge...
# 2061     ["smart", "modern", "decisive", "comfortable"]
# 2062  ["eager", "happy", "desperate", "lacking", "ab...
# 2063  ["frugal", "prudent", "prepared", "dependable"...
# 2080  ["weallthy", "stylish", "motivated", "in need"...
# 2081     ["eager", "desirous", "interested", "curious"]
# 2082  ["motivated", "hopeful", "Shopaholic", "Rich",...
# 2108  ["rich", "proud", "in the know", "modern", "in...
#
#                                                 xEffect  \
# 1778  ["none", "wear a shoe", "tear a shoe", "needs ...
# 1789  ["He buys a new helmet", "Gets a new lock", "n...
# 1790  ["smiles", "cries", "spends money", "give away...
# 1791  ["Displays caring", "Parts with money", "gets ...
# 1792  ["gets thanked", "gets praised", "Pays the bil...
# 1796              ["gets thanked", "pockets a receipt"]
# 1813     ["spends money", "interacts with sale's end."]
# 1852  ["PersonX will have more possessions.", "Perso...
# 1924  ["Has no money left", "The car is running", "g...
# 1925  ["rides the bike", "puts on helmet", "buys a h...
# 1926  ["has less money than they had before", "they ...
# 1927  ["becomes less wealthy", "is thanked for their...
# 1928  ["Loses wealth", "Will be more inclined to bru...
# 1929  ["Tests the camera", "Shows it to his friends"...
# 1930  ["PersonX smiles", "PersonX loses money", "Has...
# 1931  ["has a phone", "makes calls", "gets a new num...
# 1932  ["none", "Finds the perfect fit", "Breaks the ...
# 1933  ["phone works", "old one is thrown away", "get...
# 1934  ["PersonX grimaces at the lost of hundreds of ...
# 1935  ["gets it delivered", "is told to come back an...
# 1936       ["gets poo on floor", "gets waken at night"]
# 1937  ["trys it on when they get home", "wears it ou...
# 1938  ["gets cool this summer", "anticipation to plu...
# 1939  ["they run out of money", "can't stop smiling"...
# 1940  ["PersonX receives a receipt", "PersonX smiles...
# 1941  ["acquisition", "bargain", "takes lessons", "p...
# 1942  ["PersonX has a new possession.", "PersonX mus...
# 1943  ["is comforted", "is sad", "Feels pretty/hands...
# 1944  ["moves into the home", "furnishes the home", ...
# 1945  ["they have to move", "they spend a lot o mone...
# ...                                                 ...
# 1963  ["PersonX goes to a party", "PersonX shows off...
# 1964          ["plays tennis", "gets exercise", "none"]
# 1965  ["smiles", "get a receipt", "gets receipt", "g...
# 1966  ["PersonX gets rid of old sofa.", "PersonX mus...
# 1967  ["tries it on", "looks it up and down", "pays ...
# 1968  ["itches", "has less money than before this pu...
# 1969  ["ability to watch good movies", "has less mon...
# 1970  ["Is able to camp", "Has less room in house", ...
# 1971  ["pays to have tire installed", "Puts tire on ...
# 1972  ["gets excited to test new toaster", "gets cha...
# 1973  ["pays for the toy", "takes the toy home", "pl...
# 1974  ["gains knowledge", "gains knowledge", "drives...
# 1975  ["installs TV at home.", "watches TV for the f...
# 1976  ["hopes that is good", "spends all their money...
# 1977  ["can keep his money cards in order", "doesn't...
# 1978  ["gets compliments", "is uncomfortable", "lose...
# 1979  ["is complimented at work", "is now on time fo...
# 2055                      ["goes broke", "looks fresh"]
# 2056  ["to buy new furnitre", "to full fill of metho...
# 2057  ["gets excited", "receives compliment for new ...
# 2058  ["orders them on Amazon", "gets a delivery", "...
# 2059  ["has no more room for the old ones", "overdra...
# 2060  ["wears them to dinner", "goes back home", "ge...
# 2061  ["use the sheets", "to be a sheet for set", "n...
# 2062  ["can walk faster", "looks fashionable", "has ...
# 2063  ["has less money", "becomes less worried about...
# 2080  ["looks sharp", "attracts women", "pays for th...
# 2081  ["Is glad for the replacements", "can get rid ...
# 2082  ["PersonX goes to a wedding", "PersonX goes to...
# 2108  ["Expends money", "Spends tine searching for g...
#
#                                                 xIntent  \
# 1778  ["to be comfortable", "to be fancy", "to be fa...
# 1789  ["to be friendly.", "to be generous to other p...
# 1790                ["to help", "to show their wealth"]
# 1791  ["to purchase something for someone", "to be h...
# 1792                        ["to replace the old ones"]
# 1796  ["to be generous", "to treat the other", "to b...
# 1813  ["their friend to like them.", "to help someon...
# 1852  ["to be prepared", "new school supplies", "to ...
# 1924  ["to raplace an old battery", "to power a devi...
# 1925  ["to ride his bike to work instead of driving ...
# 1926  ["to go fishing.", "to sail on the water", "to...
# 1927  ["to write notes.", "go through the latest inf...
# 1928  ["to groom their hair", "to have a brush", "to...
# 1929  ["to take a lot of pictures.", "to replace a b...
# 1930  ["to be able to drive to work", "a car that ru...
# 1931  ["they needed to get with the times", "to repl...
# 1932  ["to sit comfortably", "to replace a broken ch...
# 1933  ["a charger that works", "to replace an old ch...
# 1934  ["something different", "new technology", "to ...
# 1935  ["new furniture.", "to have furniture to sit on"]
# 1936  ["to get a new pet.", "to protect house", "to ...
# 1937  ["to wear at a party", "to look good", "to wea...
# 1938  ["to be cooler", "to keep his cool", "cool dow...
# 1939  ["to have a new pet", "a pet", "to put into th...
# 1940  ["to have fun", "to play", "have something new...
# 1941  ["to replace an old guitar", "a new guitar", "...
# 1942             ["for self-defense", "to go shooting"]
# 1943  ["to look handsome", "to be fashionable", "to ...
# 1944  ["to improve his standard of living", "to meet...
# 1945                     ["a bigger one.", "stability"]
# ...                                                 ...
# 1963  ["to be fashionable", "to replace an old purse...
# 1964  ["they want to be able to play", "to replace h...
# 1965  ["more clothes", "a new look", "to look good",...
# 1966  ["to liven up their living room", "to replace ...
# 1967  ["to be more fashionable", "to look good for a...
# 1968       ["to be stylish.", "to add to his wardrobe"]
# 1969  ["to watch something bigger", "to splurge on t...
# 1970  ["go vacation with family", "to use it in his ...
# 1971                    ["to be able to drive", "none"]
# 1972  ["to replace his broken toasters.", "to use it...
# 1973  ["they want something new to play with", "to g...
# 1974  ["to transport goods to make living", "to driv...
# 1975  ["to watch the hockey game.", "to be entertain...
# 1976  ["to have fun", "to be entertained", "to satis...
# 1977  ["a new wallet", "to store his money", "to hav...
# 1978           ["to refresh their look", "new clothes"]
# 1979  ["happy", "to get the latest fashion", "to imp...
# 2055  ["to dress nice", "to look good", "to be buy c...
# 2056  ["to have a sofa for the living room.", "to fu...
# 2057  ["to see", "to have a new look", "to be able t...
# 2058  ["to listen to music", "to get rid of the old ...
# 2059  ["to replace old ones", "an updated product", ...
# 2060  ["an updated wardrobe", "new clothes", "to be ...
# 2061  ["to replace old sheets", "to write", "to draw...
# 2062  ["to have foot protection", "to have a pair of...
# 2063  ["new pair", "to have new socks", "to throw ol...
# 2080  ["to look good", "to wear the new clothes to a...
# 2081  ["to have new ones", "to replace old one", "to...
# 2082  ["to replace his worn out sneakers", "to feel ...
# 2108  ["to play the game with his friends.", "to be ...
#
#                                                   xNeed  \
# 1778  ["to go to the store", "decide what color they...
# 1789  ["to go to the store", "to select the colour",...
# 1790  ["to save the money", "to go to the dealership...
# 1791  ["to know what PersonY needs", "to look for wh...
# 1792  ["save up money", "go to store", "to know Pers...
# 1796  ["to find out y's size", "to go to the shoe st...
# 1813  ["get money", "go to the store", "money", "an ...
# 1852  ["to go to the store", "to know what school su...
# 1924  ["to go to the store", "to take out their wall...
# 1925  ["to go to the store", "to choose what to purc...
# 1926  ["to go to the boat store", "to narrow down th...
# 1927  ["go to the store", "pay the cashier", "To sel...
# 1928  ["drive to store", "walk into store", "to go t...
# 1929  ["to look up different cameras", "to make a ch...
# 1930  ["Save a lot of money.", "Find a good deal.", ...
# 1931  ["to research phones", "to choose the cell pho...
# 1932  ["to go to the store", "to pay the cashier", "...
# 1933  ["to find out what kind of charger he needs.",...
# 1934  ["Finds out his broke.", "Go to the store.", "...
# 1935  ["to bargain shop", "to visit the furniture st...
# 1936  ["Go to a pet shop", "Choose a dog", "give mon...
# 1937  ["to get her wallet", "to choose a dress", "to...
# 1938  ["To make a selection", "To have money", "to p...
# 1939  ["get supplies", "place water in the bowl so i...
# 1940  ["get bored with old game", "get a discount co...
# 1941  ["to compare guitars", "to go shopping", "to t...
# 1942  ["get money", "go to the gun store", "to compa...
# 1943  ["to find out what hat they want", "to find wh...
# 1944  ["save money", "find a home to buy", "shop for...
# 1945  ["save money", "look for good prices", "They s...
# ...                                                 ...
# 1963  ["To save money", "To find the right store", "...
# 1964              ["to get money", "decide its colour"]
# 1965  ["to go to the clothing store", "to pick out a...
# 1966  ["to get rid of old sofa", "to go shopping", "...
# 1967  ["leave their old suit", "to meet people, to g...
# 1968  ["go to store", "decide what kind of sweater t...
# 1969  ["money", "to get rid of old television", "to ...
# 1970  ["to go to a sporting goods store.", "to bring...
# 1971  ["to go to the store", "to pick a tire", "to f...
# 1972  ["to go to the store", "to buy some bread", "t...
# 1973  ["to research what he wants exactly", "the cos...
# 1974  ["save up money", "shop for new vehicle", "to ...
# 1975  ["to save up money", "to find the best deal on...
# 1976  ["to look for sales", "to go to the store", "a...
# 1977  ["to go to a store", "to look through the sele...
# 1978  ["to look online for clothes", "to go to the m...
# 1979  ["to open his wallet", "to go to the watch sto...
# 2055  ["tries on clothes", "goes to store", "To have...
# 2056  ["to find a furniture store.", "to determine w...
# 2057  ["to shop for new glasses", "to take an eye ex...
# 2058  ["go to the store", "make money", "to get onli...
# 2059  ["money", "to visit a store", "goes to the mal...
# 2060  ["to go to the store", "to try some on", "to g...
# 2061  ["to get money ready", "select the sheets", "g...
# 2062  ["earn money", "pick out shoes", "car", "money...
# 2063  ["go to store", "select socks", "to go to the ...
# 2080  ["to earn money", "to drive to the mall", "to ...
# 2081  ["make money", "go to the store", "money", "to...
# 2082  ["to save money", "to go to the store", "To sh...
# 2108  ["saves their money", "reads the reviews", "vi...
#
#                                                  xReact  \
# 1778  ["comfortable", "successful", "happy", "satisf...
# 1789  ["like a boss.", "happy", "generous", "proud",...
# 1790                                   ["glad", "rich"]
# 1791       ["helpful", "charitable", "giving", "happy"]
# 1792                      ["good for giving something"]
# 1796  ["generous", "caring", "satisfied", "proud", "...
# 1813  ["like a good friend.", "good", "helpful", "ha...
# 1852            ["accomplished", "prepared", "anxious"]
# 1924  ["satisfied", "happy", "happy", "relieved", "h...
# 1925                                    ["determined."]
# 1926                 ["amazing.", "hedonistic", "smug"]
# 1927  ["excited to write on it.", "great he found th...
# 1928  ["accomplished", "satisfied", "like they finis...
# 1929         ["happy.", "excited", "ready", "powerful"]
# 1930  ["super excited because he just bought a new c...
# 1931                      ["happy", "scared", "happy."]
# 1932   ["comfortable", "satisfied", "happy", "relaxed"]
# 1933  ["like he handled a problem", "satisfied", "re...
# 1934  ["happy to have something new", "excited", "cu...
# 1935                  ["like an adult.", "responsible"]
# 1936  ["happy and relaxed", "excitement", "enjoying"...
# 1937  ["happy", "satisfied", "excited to wear dress"...
# 1938  ["cooled off", "satisfied", "happy", "better",...
# 1939  ["happy with their new friend.", "excited", "h...
# 1940  ["happy", "excited", "impatient", "competitive...
# 1941  ["happy with purchase", "accomplished", "excit...
# 1942                                         ["secure"]
# 1943        ["happy and contented", "stylish", "happy"]
# 1944  ["overjoyed", "contented", "proud of his/her p...
# 1945                           ["positive", "relieved"]
# ...                                                 ...
# 1963            ["excited", "satisfied", "fashionable"]
# 1964  ["happy", "energized", "happy.", "refreshed", ...
# 1965  ["excited about the look", "accomplished", "re...
# 1966  ["happy", "content", "satisfied", "cheerful", ...
# 1967                                 ["happy", "happy"]
# 1968                               ["fresh", "excited"]
# 1969         ["proud", "excited", "happy", "satisfied"]
# 1970                             ["happy and enjoying"]
# 1971            ["relieved", "safer with the new tire"]
# 1972  ["happy.", "happy", "good", "happy", "satisfied"]
# 1973           ["happy", "excited", "happy", "excited"]
# 1974  ["happier to be busy working with his new truc...
# 1975         ["like a grown up.", "happy", "satisfied"]
# 1976  ["happy", "interested", "entertained", "less b...
# 1977  ["satisfied", "rich and wealthy", "satisfied t...
# 1978                               ["anew", "fabulous"]
# 1979   ["good", "happy", "like a showoff", "satisfied"]
# 2055   ["good looking", "happy", "satisfied", "exited"]
# 2056                   ["happy.", "happy", "satisfied"]
# 2057          ["enhanced", "good looking", "healthier"]
# 2058        ["happy", "satisfied", "glad", "satisfied"]
# 2059       ["competent", "relieved", "glad", "content"]
# 2060  ["excited to have new clothing", "satisfied wi...
# 2061  ["happy with new sheets", "feels happy to star...
# 2062  ["happy", "secure", "satisfied", "happy", "att...
# 2063  ["happy", "happy", "good about himself", "comf...
# 2080       ["happy", "excited", "satisfied", "excited"]
# 2081  ["satisfied with the new product", "fresh", "s...
# 2082  ["fresh", "comfortable", "sporty", "satisfied"...
# 2108                   ["happy.", "happier", "excited"]
#
#                                                   xWant           prefix split
# 1778  ["to wear them", "to throw away the old ones",...  ["buys", "new"]   trn
# 1789  ["to go for a ride", "show it to his parents",...  ["buys", "new"]   trn
# 1790  ["to gift him", "to reward him", "to help Pers...  ["buys", "new"]   trn
# 1791  ["to bring it to Persony", "to hug PersonY", "...  ["buys", "new"]   trn
# 1792  ["save back money", "look at PersonY", "to wra...  ["buys", "new"]   trn
# 1796  ["to wrap them up", "to give them to y", "try ...  ["buys", "new"]   trn
# 1813  ["meet with Person Y", "give them the new gift...  ["buys", "new"]   trn
# 1852  ["to cover the books", "to pack everything in ...  ["buys", "new"]   trn
# 1924  ["to install the new battery", "to use the ite...  ["buys", "new"]   trn
# 1925  ["to ride home", "to get a helmet", "ride the ...  ["buys", "new"]   trn
# 1926  ["to bring the boat to water", "to drive the b...  ["buys", "new"]   trn
# 1927  ["read the story", "put a bookmark in it", "To...  ["buys", "new"]   trn
# 1928  ["takes brush out of packaging", "brushes hair...  ["buys", "new"]   trn
# 1929  ["to take beautiful pictures", "to share those...  ["buys", "new"]   trn
# 1930  ["Test drive to make sure rides nice.", "Show ...  ["buys", "new"]   trn
# 1931  ["to set the new phone up", "to install apps o...  ["buys", "new"]   trn
# 1932  ["to take it home", "to put it together", "tra...  ["buys", "new"]   trn
# 1933  ["to plug in his charger.", "to drive home.", ...  ["buys", "new"]   trn
# 1934  ["Sets it up.", "Uses it for work.", "to bring...  ["buys", "new"]   trn
# 1935  ["to redecorate room", "to rearrange room", "t...  ["buys", "new"]   trn
# 1936  ["give the dog a name", "feed the dog", "Bring...  ["buys", "new"]   trn
# 1937  ["to show off the dress", "to attend the party...  ["buys", "new"]   trn
# 1938  ["To pay for the fan", "To get the fan install...  ["buys", "new"]   trn
# 1939  ["make sure to lift if over the scanners when ...  ["buys", "new"]   trn
# 1940  ["have a lot of fun with the new game", "excha...  ["buys", "new"]   trn
# 1941  ["to bring the guitar home", "to play the guit...  ["buys", "new"]   trn
# 1942  ["be a gun owner", "have their own protection"...  ["buys", "new"]   trn
# 1943  ["to look good", "to have shade", "protection ...  ["buys", "new"]   trn
# 1944  ["to move in", "to have a house warming party"...  ["buys", "new"]   trn
# 1945  ["to a have his own home", "to live alone", "P...  ["buys", "new"]   trn
# ...                                                 ...              ...   ...
# 1963  ["To be fashionable", "To carry items", "to ta...  ["buys", "new"]   trn
# 1964  ["plays tennis", "shows it to their friends", ...  ["buys", "new"]   trn
# 1965  ["to take the shirt home", "to try on the shir...  ["buys", "new"]   trn
# 1966  ["to have a nicely furnished home", "to replac...  ["buys", "new"]   trn
# 1967  ["go to shop and buy a new suit", "no", "to go...  ["buys", "new"]   trn
# 1968  ["try on new clothes", "show outfit off to fri...  ["buys", "new"]   trn
# 1969  ["to watch new television", "to have nice elec...  ["buys", "new"]   trn
# 1970  ["to bring the tent home.", "to plan to go cam...  ["buys", "new"]   trn
# 1971  ["to drive home", "to pay the bill", "replace ...  ["buys", "new"]   trn
# 1972  ["to read the manual", "to plug it in", "to to...  ["buys", "new"]   trn
# 1973  ["to bring it home", "put it together and lear...  ["buys", "new"]   trn
# 1974  ["to clean new truck", "to drive in truck", "d...  ["buys", "new"]   trn
# 1975  ["to watch television", "to show people their ...  ["buys", "new"]   trn
# 1976  ["to play the video game", "to put the game in...  ["buys", "new"]   trn
# 1977  ["to transfer their items", "to use it", "to r...  ["buys", "new"]   trn
# 1978  ["to go out on a date", "to go to a job interv...  ["buys", "new"]   trn
# 1979  ["to insure the watch", "to show it off", "to ...  ["buys", "new"]   trn
# 2055  ["to wear a new suit", "look professional", "m...  ["buys", "new"]   trn
# 2056  ["to make arrangements to have their new furni...  ["buys", "new"]   trn
# 2057  ["to try on the new glasses", "to bring the ne...  ["buys", "new"]   trn
# 2058  ["listen to music", "watch a movie", "to liste...  ["buys", "new"]   trn
# 2059  ["to have new posessions", "to enjoy a purchas...  ["buys", "new"]   trn
# 2060  ["to wear them", "to give them as a gift", "to...  ["buys", "new"]   trn
# 2061  ["to decorate his new home", "to gift it to hi...  ["buys", "new"]   trn
# 2062  ["victory", "give best", "to clean them", "to ...  ["buys", "new"]   trn
# 2063  ["pay money", "get receipt", "to leave the sto...  ["buys", "new"]   trn
# 2080  ["to drive home", "to wear his new clothes", "...  ["buys", "new"]   trn
# 2081  ["take the new ones home", "use the new ones",...  ["buys", "new"]   trn
# 2082  ["to wear the shoes", "to buy other things", "...  ["buys", "new"]   trn
# 2108  ["play online", "beat all competitors", "to pl...  ["buys", "new"]   trn
#
# [77 rows x 12 columns]

# %%
df['prefix'][0]
# Out:
# '["better", "go"]'

# %%
df
# Out:
#                                          event  \
# 0                         PersonX 'd better go
# 1              PersonX abandons ___ altogether
# 2          PersonX abandons the ___ altogether
# 3             PersonX abolishes ___ altogether
# 4          PersonX abolishes ___ in the states
# 5         PersonX abolishes the ___ altogether
# 6                 PersonX about to get married
# 7                     PersonX absolutely loved
# 8                 PersonX absolutely loved ___
# 9                  PersonX absolutely loved it
# 10                   PersonX absorbs every ___
# 11              PersonX abuses PersonX's power
# 12           PersonX accepts PersonX's diploma
# 13         PersonX accepts PersonY appointment
# 14          PersonX accepts PersonY invitation
# 15               PersonX accepts PersonY offer
# 16              PersonX accepts PersonY thanks
# 17           PersonX accepts PersonY's apology
# 18        PersonX accepts PersonY's invitation
# 19             PersonX accepts PersonY's offer
# 20          PersonX accepts PersonY's proposal
# 21       PersonX accepts PersonY's resignation
# 22     PersonX accepts ___ as PersonX's savior
# 23             PersonX accepts ___ in exchange
# 24              PersonX accepts ___ in payment
# 25                 PersonX accepts another ___
# 26                   PersonX accepts every ___
# 27                  PersonX accepts god 's ___
# 28                     PersonX accepts happily
# 29                PersonX accepts into college
# ...                                        ...
# 24282        PersonX writes an essay for class
# 24283               PersonX writes another ___
# 24284              PersonX writes another book
# 24285                      PersonX writes back
# 24286                     PersonX writes books
# 24287                 PersonX writes every ___
# 24288            PersonX writes home about ___
# 24289        PersonX writes in PersonX's diary
# 24290                   PersonX writes letters
# 24291                     PersonX writes music
# 24292                     PersonX writes poems
# 24293                    PersonX writes poetry
# 24294             PersonX writes short stories
# 24295                     PersonX writes songs
# 24296                   PersonX writes stories
# 24297                  PersonX writes the book
# 24298                 PersonX writes the essay
# 24299                 PersonX writes the paper
# 24300                 PersonX writes the story
# 24301       PersonX writes with PersonX's hand
# 24302            PersonX yanks PersonY's chain
# 24303                       PersonX yells back
# 24304                      PersonX yells bingo
# 24305                   PersonX yells for help
# 24306                   PersonX yells silently
# 24307                   PersonX yells surprise
# 24308                    PersonX yelps in pain
# 24309            PersonX yields PersonY income
# 24310       PersonX youngest PersonY president
# 24311     PersonX zig when PersonX shoulds zag
#
#                                                  oEffect  \
# 0                                       ["none", "none"]
# 1                                       ["none", "none"]
# 2                               ["none", "none", "none"]
# 3                               ["none", "none", "none"]
# 4                                               ["none"]
# 5      ["none", "the people lost the documents", "the...
# 6      ["their partner is in a legal relationship", "...
# 7                                       ["none", "none"]
# 8                                               ["none"]
# 9                               ["none", "none", "none"]
# 10                                              ["none"]
# 11     ["are told what to do", "given unfair conseque...
# 12                              ["none", "none", "none"]
# 13     ["persony shakes personx hand", "persony taps ...
# 14     ["PersonY adds PersonX to the guest list", "Pe...
# 15     ["none", "none", "pay person X", "get item the...
# 16     ["feel even", "agree with one another", "think...
# 17     ["become friends", "settle the score", "they d...
# 18     ["smiles", "loses money hosting event", "none"...
# 19     ["shakes hands", "smiles", "shakes hands", "si...
# 20                ["signs the paper", "get's a receipt"]
# 21     ["become unemployed", "receive their retiremen...
# 22     ["is accepted", "is thought about", "none", "s...
# 23                                      ["none", "none"]
# 24     ["Ability to pay PersonX", "Increased opportun...
# 25                              ["none", "none", "none"]
# 26     ["none", "none", "frowns", "smacks own forehead"]
# 27                                              ["none"]
# 28     ["none", "instructs PersonX", "says you're wel...
# 29     ["none", "none", "hopes they do well", "has to...
# ...                                                  ...
# 24282                                           ["none"]
# 24283                           ["none", "none", "none"]
# 24284                           ["none", "none", "none"]
# 24285  ["gets a letter", "heart rate increases", "non...
# 24286                                   ["none", "none"]
# 24287                           ["none", "none", "none"]
# 24288        ["none", "none", "Read it", "Cry and pray"]
# 24289                           ["none", "none", "none"]
# 24290  ["receives the letter", "reads the letter", "n...
# 24291                           ["none", "none", "none"]
# 24292                                   ["none", "none"]
# 24293                                   ["none", "none"]
# 24294  ["none", "none", "publishers evaluate the cont...
# 24295                           ["none", "none", "none"]
# 24296                           ["none", "none", "none"]
# 24297                           ["none", "none", "none"]
# 24298                                   ["none", "none"]
# 24299  ["The scorer givesd the paper a grade.", "Peop...
# 24300                           ["none", "none", "none"]
# 24301                                   ["none", "none"]
# 24302  ["Prented to go along", "Gives up on X", "crie...
# 24303                           ["none", "none", "none"]
# 24304                                   ["none", "none"]
# 24305              ["none", "works", "is done worrying"]
# 24306                           ["none", "none", "none"]
# 24307  ["none", "becomes startled", "heart rate incre...
# 24308                                   ["none", "none"]
# 24309  ["Person Y thanks person X", "Person Y saves s...
# 24310                                           ["none"]
# 24311  ["are ran into by PersonX", "fall down and get...
#
#                                                   oReact  \
# 0                                       ["none", "none"]
# 1                                           ["dejected"]
# 2                                             ["defeat"]
# 3                                               ["none"]
# 4                                               ["none"]
# 5                           ["grateful", "disrespected"]
# 6       ["like they have a lifelong companion", "happy"]
# 7                                             ["happy."]
# 8                               ["none", "none", "none"]
# 9                                       ["none", "none"]
# 10                                      ["none", "none"]
# 11             ["humiliated", "sad", "angry", "cheated"]
# 12                          ["proud", "excited", "none"]
# 13                          ["excited", "none", "happy"]
# 14     ["glad", "good", "also happy", "thankful", "ha...
# 15                    ["giving", "none", "disappointed"]
# 16                     ["grateful", "thankful", "happy"]
# 17                                 ["happy", "grateful"]
# 18           ["happy", "happy personx accepted", "glad"]
# 19     ["they have given a good service", "satisfied....
# 20     ["excited", "happy their proposal was accepted...
# 21                             ["lost", "none", "happy"]
# 22        ["none", "all powerful", "adored", "believed"]
# 23                                      ["none", "none"]
# 24                                              ["none"]
# 25                       ["happy about his acceptance."]
# 26                                      ["none", "none"]
# 27                                              ["none"]
# 28                                      ["glad", "none"]
# 29                                      ["none", "none"]
# ...                                                  ...
# 24282                          ["none", "none", "happy"]
# 24283          ["better after reading the book", "none"]
# 24284                           ["none", "none", "none"]
# 24285           ["appreciated", "none", "reciprocated."]
# 24286                                   ["none", "none"]
# 24287                                   ["none", "none"]
# 24288                                          ["happy"]
# 24289                           ["none", "none", "none"]
# 24290                   ["engaged", "none", "satisfied"]
# 24291  ["none", "entertained by his songs", "interest...
# 24292                                   ["none", "none"]
# 24293                                   ["none", "none"]
# 24294                                   ["none", "none"]
# 24295  ["grateful", "entertained", "amused", "wowed",...
# 24296                       ["none", "informed", "none"]
# 24297                  ["none", "more informed", "none"]
# 24298                                   ["none", "none"]
# 24299  ["none", "informed by an authoritative figure ...
# 24300                           ["none", "none", "good"]
# 24301                           ["none", "none", "none"]
# 24302      ["silly and happy", "annoyed and aggravated"]
# 24303  ["angry", "annoyed", "upset", "annoyed", "info...
# 24304  ["annoyed", "frustrated", "unhappy", "none", "...
# 24305  ["helpful", "helpful", "anxious to help.", "ne...
# 24306                                   ["none", "none"]
# 24307       ["surprised", "startled", "happy", "happy."]
# 24308          ["none", "compassion", "concern", "none"]
# 24309                            ["insecure finacially"]
# 24310                                           ["none"]
# 24311                                   ["none", "none"]
#
#                                                    oWant  \
# 0                               ["none", "none", "none"]
# 1      ["none", "none", "to find a new job for him", ...
# 2      ["none", "to do something else as well", "they...
# 3      ["to be free", "to do things of their own wish...
# 4      ["to celebrate", "to write about the new law",...
# 5      ["to publish an article", "to find other pursu...
# 6      ["to spend the rest of their life with personx...
# 7      ["none", "to marry him", "to accompany him all...
# 8                               ["none", "none", "none"]
# 9                               ["none", "none", "none"]
# 10                              ["none", "none", "none"]
# 11     ["report PersonX to HR", "get PersonX fired", ...
# 12                              ["none", "none", "none"]
# 13     ["to have a good appointment", "to follow up w...
# 14     ["prepare to hang out with PersonX", "wait for...
# 15     ["to let PersonX know of the rules with the of...
# 16             ["none", "to help him", "to support him"]
# 17     ["to be forgiven", "to move on", "say sorry", ...
# 18                                      ["none", "none"]
# 19     ["to take the money", "to hand over the goods"...
# 20     ["to make plans", "to buy wedding bands", "to ...
# 21     ["curse PersonX out", "leave the building", "s...
# 22                              ["none", "none", "none"]
# 23                              ["none", "none", "none"]
# 24     ["to put the check in their account", "to help...
# 25     ["none", "none", "to make a handshake deal", "...
# 26     ["to thank PersonX", "to tell others", "to kee...
# 27                              ["none", "none", "none"]
# 28     ["to throw a party", "to clean up the mess", "...
# 29     ["to celebrate with their family/friend", "to ...
# ...                                                  ...
# 24282  ["to read the essay", "to get a good grade", "...
# 24283                                   ["none", "none"]
# 24284  ["none", "to read the sequel", "to buy the boo...
# 24285  ["to wait for the letter", "to wonder when Per...
# 24286                                   ["none", "none"]
# 24287  ["none", "checks their inbox/mailbox", "reads ...
# 24288  ["none", "to read the letter", "to respond to ...
# 24289                                   ["none", "none"]
# 24290  ["none", "none", "read personX's letters", "re...
# 24291                                   ["none", "none"]
# 24292  ["to read the poem", "to critique the poem", "...
# 24293  ["none", "to read the poetry", "to critique th...
# 24294                           ["none", "none", "none"]
# 24295                           ["none", "none", "none"]
# 24296  ["none", "none", "to read the stories", "to ed...
# 24297                           ["none", "none", "none"]
# 24298  ["to read the essay", "to grade the essay", "n...
# 24299  ["none", "to read the paper", "to grade the pa...
# 24300  ["none", "read the story", "talk about the sto...
# 24301                   ["none", "none", "none", "none"]
# 24302  ["to chase thief", "to log complain", "push Pe...
# 24303  ["none", "to show why they are upset at X", "t...
# 24304                           ["none", "none", "none"]
# 24305  ["none", "to help them out", "to make sure the...
# 24306                                   ["none", "none"]
# 24307  ["to thank them", "to open their gift", "to la...
# 24308                           ["none", "none", "none"]
# 24309  ["accept the payment", "thank PersonX", "to th...
# 24310   ["to do their best", "to get reelected", "none"]
# 24311                                           ["none"]
#
#                                                    xAttr  \
# 0      ["avoidant", "weak", "hurried", "late", "Tardy...
# 1      ["impatient", "decisive", "undependable", "fic...
# 2      ["flaky", "irresponsible", "desperate", "convi...
# 3      ["ruthless", "destructive", "strict", "determi...
# 4      ["bold", "authoritative", "determined", "heroi...
# 5      ["dedicated", "furious", "powerful", "influenc...
# 6      ["excited", "anxious", "anxious", "nervous", "...
# 7      ["caring", "faithful", "Passionate", "Caring",...
# 8      ["compassionate", "friendly", "hungry", "excit...
# 9      ["enthused", "appreciative", "satisfied", "con...
# 10         ["Conscious", "Aware", "unwasteful", "smart"]
# 11     ["out of line", "irresponsible", "mean", "conf...
# 12     ["succesfull", "educated", "successful", "sati...
# 13     ["Booked", "Timely", "humble", "accomplished",...
# 14     ["social", "interesting", "grateful", "forward...
# 15     ["intelligent", "resourceful", "humble", "fair...
# 16     ["grateful", "happy", "polite", "friendly", "h...
# 17     ["empathetic", "frank", "amiable", "compassion...
# 18     ["excited", "loved", "Outgoing", "Social", "so...
# 19     ["Trusting", "Kind", "considerate", "friendly"...
# 20     ["Trusting", "Agreeable", "amenable", "coopera...
# 21     ["Understanding", "Accepting", "saddened", "di...
# 22     ["thankful", "grateful", "naive", "faithful", ...
# 23     ["agreeable", "accepting", "reasonable", "fair...
# 24     ["Facilitating", "Engaged", "bribeable", "unet...
# 25     ["flexible", "mobile", "powerful", "wise", "av...
# 26     ["accepting", "trusting", "satisfied", "apathe...
# 27     ["grateful", "god-fearing", "decisive", "willf...
# 28     ["grateful", "appreciative", "gracious", "than...
# 29     ["hopeful", "responsible", "smart", "intellige...
# ...                                                  ...
# 24282  ["intelligent", "capable", "capable", "prepared"]
# 24283  ["consistent", "responsible", "hard-working", ...
# 24284  ["creative", "productive", "talented", "skille...
# 24285  ["intellectual", "knowledgeable", "friendly", ...
# 24286  ["creative", "talented", "creative", "writer",...
# 24287  ["attentive", "responsible", "dedicated", "har...
# 24288  ["adventurous", "loyal", "thoughtful", "sharin...
# 24289  ["thoughtful", "reflective", "Thoughtful", "Cr...
# 24290     ["done", "finished", "creative", "thoughtful"]
# 24291  ["artsy", "creative", "creative", "artistic", ...
# 24292  ["creative", "expressive", "romantic", "creati...
# 24293  ["creative", "expressive", "Artistic", "Creati...
# 24294  ["hard-working", "authorial", "creative", "an ...
# 24295  ["imaginative", "talented", "skilled", "creati...
# 24296  ["creative", "inventive", "industrious", "verb...
# 24297  ["skillful", "knowledgeable", "dedicated", "ta...
# 24298  ["creative", "determined", "intelligent", "har...
# 24299   ["Working", "Creating", "competent", "educated"]
# 24300  ["creative", "focused", "patient", "smart", "d...
# 24301  ["calm", "eager", "controlling", "dominant", "...
# 24302  ["playful", "engaged", "funny", "mean", "humor...
# 24303  ["assertive", "sensitive", "aggressive", "aggr...
# 24304  ["Active", "Alert", "Engaged", "Winner", "Prou...
# 24305  ["scared", "petrified", "scared", "helpless", ...
# 24306  ["scared", "silent", "bold", "unique", "upset"...
# 24307  ["enjoyment", "surprised", "excited", "happy",...
# 24308  ["injured", "shocked", "suffering", "miserable...
# 24309  ["intelligent", "smart", "capable", "determine...
# 24310  ["motivated", "intelligent", "talented", "accl...
# 24311  ["Unfavorable", "Young", "naughty", "mischievo...
#
#                                                  xEffect  \
# 0      ["She ran to the bathroom", "She finally made ...
# 1      ["gets a reputation as a quitter", "hangs head...
# 2      ["eats all the cakes", "abandons his diets too...
# 3      ["loss money", "change house", "get loan", "pe...
# 4                                               ["none"]
# 5      ["set free", "become independent", "lost the d...
# 6      ["they are in a legal relationship", "their le...
# 7          ["none", "gains knowledge", "is entertained"]
# 8      ["smiles when they think about the event", "sm...
# 9      ["stomped feet", "laughed", "takes it home", "...
# 10                                              ["none"]
# 11     ["becomes authoratarian", "is ostracized", "is...
# 12     ["PersonX graduates high school", "PersonX gra...
# 13     ["personx travels to appointment", "personx sh...
# 14     ["PersonX mails an RSVP to PersonY", "PersonX ...
# 15     ["Person X marks the offer on his calendar", "...
# 16     ["feels grateful", "proud", "thinks more of pe...
# 17     ["paid his debt", "is relieved", "they talk to...
# 18     ["learns date and time of event", "smiles", "g...
# 19     ["shakes hands", "goes over the agreement", "s...
# 20               ["signs the paper", "earns some money"]
# 21     ["gets overwhelmed with work", "makes more mon...
# 22     ["gains acceptance", "thinks about person x", ...
# 23     ["none", "banks his money", "helps people figu...
# 24     ["Has increased business opportunities", "Has ...
# 25     ["has to give notice", "smiles at the better w...
# 26     ["starts to write on a book", "looks for peopl...
# 27                                              ["none"]
# 28            ["none", "uses an item", "thanks someone"]
# 29     ["Studies", "Gets a loan", "PersonX gets assig...
# ...                                                  ...
# 24282                   ["hands it in", "proofreads it"]
# 24283  ["sends book to an editor", "publisehs a book"...
# 24284  ["collects compensation", "gets it signed", "C...
# 24285  ["none", "gets a call", "gets a letter", "gets...
# 24286  ["gets a contract", "becomes famous", "gain kn...
# 24287  ["reflects", "picks up pen", "fliips paper", "...
# 24288  ["signs the letter", "sends out the mail", "wa...
# 24289  ["reads the to do list", "tears the pages", "h...
# 24290  ["seals it in an envelope", "takes it to the p...
# 24291  ["gets corrected by master", "got published", ...
# 24292  ["becomes famous", "gets a girlfriend", "hand ...
# 24293  ["Makes words on page", "Expends brain power",...
# 24294  ["PersonX submits their stories to publishers"...
# 24295  ["none", "take notes", "thinking deep", "watch...
# 24296  ["publishes a book", "collaborates on a short ...
# 24297  ["hands feel tired", "sees manuscript", "gets ...
# 24298  ["uses brain power", "spends time", "gains kno...
# 24299  ["turns the paper in", "sees the paper's grade...
# 24300  ["accomplished", "becomes published", "gets id...
# 24301  ["HIS HAND IS SORE", "HE CRITIQUES HIS WRITING...
# 24302  ["Tries to fool Y", "Thinks they convinced Y",...
# 24303  ["body temperature rises", "clenches fist", "r...
# 24304  ["smiles", "blushes", "gets robbed", "applauded"]
# 24305  ["people come over", "gets assistance", "gets ...
# 24306  ["feels angry", "feels relieved after yelling....
# 24307  ["gets yelled at", "gets punched", "none", "no...
# 24308  ["shouts for help", "sees a doctor", "takes me...
# 24309  ["allows person Y work in his office", "treats...
# 24310                                           ["none"]
# 24311  ["stumble over someone else", "gets hurt", "mi...
#
#                                                  xIntent  \
# 0       ["to go somewhere else more important.", "none"]
# 1                                         ["put a stop"]
# 2                           ["to appear not interested"]
# 3                        ["give a punishment in person"]
# 4                     ["this is unhappiness for people"]
# 5                      ["to end it", "to do it his way"]
# 6      ["to share his life with someone", "to marry s...
# 7                                          ["to marry."]
# 8      ["to see different places", "to enjoy", "to ex...
# 9                                       ["none", "none"]
# 10     ["moment", "to completely understand his posit...
# 11     ["to profit from his position", "to get ahead ...
# 12       ["to graduate from high school", "to graduate"]
# 13     ["to have a job", "to help", "to take on the r...
# 14     ["to enjoy his time", "the appreciation", "to ...
# 15            ["to gain something", "job", "to be paid"]
# 16     ["to be gracious", "as pleasure", "to be accep...
# 17     ["to feel peaceful with persony", "to be gener...
# 18     ["to be polite", "to see persony", "to not dis...
# 19     ["to buy the things", "to obtain something.", ...
# 20     ["wants to get married", "to move on with the ...
# 21                     ["none", "none", "to be sincere"]
# 22     ["to be religious", "to dedicate oneself", "to...
# 23            ["happy", "accepts the dress in exchange"]
# 24                                        ["to be nice"]
# 25                                              ["none"]
# 26     ["to be agreeable", "to be as non-confrontatio...
# 27                                              ["none"]
# 28                   ["none", "to take the opportunity"]
# 29                          ["to going college", "none"]
# ...                                                  ...
# 24282  ["to have a good grade.", "to pass", "to revea...
# 24283  ["to be famous", "because he likes doing it as...
# 24284  ["tell a story", "to sell books", "to get rich...
# 24285  ["to return communication", "to respond to the...
# 24286     ["to tell stories", "to follow their passion"]
# 24287      ["to enjoy writing", "discipline", "routine"]
# 24288                 ["to stay in contact with family"]
# 24289  ["to articulate their thoughts", "to comminica...
# 24290  ["to communicate", "a pen pale", "to thank peo...
# 24291  ["to perform", "to express himself", "to compo...
# 24292  ["to express his writing skills", "to express ...
# 24293                  ["to be artsy", "to be creative"]
# 24294  ["become poet", "become author", "to be a writ...
# 24295  ["to express themselves through music and lyri...
# 24296  ["to be  a writer", "to prove him/herself", "t...
# 24297  ["to be an author", "to get published", "to sh...
# 24298  ["to finish work", "wants to make a good argum...
# 24299  ["finish the assignment.", "it to be informati...
# 24300  ["to share their ideas", "to do their job", "t...
# 24301  ["to send a letter", "to write personx's hand"...
# 24302  ["to be a jokester.", "to joke around and make...
# 24303  ["to respond", "to make their point known", "t...
# 24304  ["to win", "to get a prize", "to win the game"...
# 24305  ["to be heard", "to come out of the pit he had...
# 24306  ["to express frustration", "to quietly express...
# 24307  ["to surprise someone", "to celebrate a birthd...
# 24308          ["none", "none", "to express their pain"]
# 24309         ["they don't want them to make that much"]
# 24310                                           ["none"]
# 24311                                   ["none", "none"]
#
#                                                    xNeed  \
# 0                               ["none", "none", "none"]
# 1      ["Plows the field.", "Gets exhausted from it."...
# 2      ["none", "to get frustrated", "to determine it...
# 3      ["to have a plan", "to have a reason", "to kno...
# 4      ["to find a problem", "to find out to stop tha...
# 5      ["find a lawyer", "file a lawsuit", "to gather...
# 6      ["meet someone", "get engaged", "to meet someo...
# 7                                       ["none", "none"]
# 8      ["to see what they want", "to try it out", "no...
# 9                               ["none", "none", "none"]
# 10     ["none", "to walk around and take notes", "to ...
# 11     ["to become a manager", "to have people work f...
# 12     ["attended school", "take final exams", "go to...
# 13     ["to clear spot in schedule", "to reserve appo...
# 14     ["know PersonY", "be invited by PersonY", "non...
# 15     ["to try and counter offer", "to ask PersonY f...
# 16           ["to get talk to Y", "to says thanks to Y"]
# 17     ["to have been offended in the first place", "...
# 18          ["none", "receive a card", "reply the card"]
# 19     ["none", "to meet with person Y", "to read the...
# 20     ["to date", "to fall in love", "to propose", "...
# 21     ["reprimand PersonY", "find a replacement", "n...
# 22     ["none", "to believe in God", "to frequent chu...
# 23     ["none", "to be a trader", "to want to comprom...
# 24     ["to do some work", "to of been hired", "to ma...
# 25     ["none", "to be offered something", "to get so...
# 26     ["none", "to appreciate it", "to be alright wi...
# 27     ["to contemplate in silence", "to think about ...
# 28      ["to get a phone call", "to be invited", "none"]
# 29     ["to get good grades in high school", "to appl...
# ...                                                  ...
# 24282  ["to learn the subject", "to get out supplies"...
# 24283  ["purchase pen", "purchase paper", "to brainst...
# 24284  ["to write the first book", "to research", "to...
# 24285  ["to get out a pen", "to get out a piece of pa...
# 24286  ["pen", "paper", "to love writing", "to know h...
# 24287  ["learn or look up every \u2014\u2014\u2014", ...
# 24288  ["to take a pen", "to read a letter", "to get ...
# 24289  ["to like writing", "to think about what they ...
# 24290  ["to buy paper for the letter", "to find a pen...
# 24291  ["figure out melodies on the piano", "to play ...
# 24292  ["to think of what to write", "to get paper an...
# 24293  ["to buy a pen and writing pad", "to sit somew...
# 24294  ["paper", "pen", "to come up with a plot", "to...
# 24295  ["to like writing songs", "to like imagining w...
# 24296  ["think of a story to write", "brainstorm idea...
# 24297  ["Book", "Pen", "to have a topic to write abou...
# 24298  ["to do the research", "to find a topic", "kno...
# 24299  ["go to school", "take pen from compass", "to ...
# 24300  ["to think of a theme", "to get paper", "gathe...
# 24301  ["none", "to pick up a pencil", "to get a piec...
# 24302  ["to be in fight", "to be a thief", "find Pers...
# 24303  ["to be in a heated argument with someone", "t...
# 24304  ["to be playing bingo", "to have all the numbe...
# 24305  ["none", "to be in trouble", "to hope someone ...
# 24306  ["to get angry.", "to go to a public place whe...
# 24307  ["to know they are going to be their", "to pla...
# 24308          ["get hurt", "fall down", "none", "none"]
# 24309  ["access to the information", "PersonY's permi...
# 24310  ["none", "to stand up for elections", "to ask ...
# 24311                                           ["none"]
#
#                                                   xReact  \
# 0      ["the person feels happy since he arrived at h...
# 1                                      ["authoritative"]
# 2                                        ["pressurized"]
# 3                                         ["he was sad"]
# 4                                                ["sad"]
# 5                        ["happy", "like he's the boss"]
# 6      ["like he has someone he feels that way about"...
# 7                                          ["romantic."]
# 8      ["happy", "satisfied", "excited", "pleasant", ...
# 9          ["ecstatic over his gift", "happy", "joyful"]
# 10     ["very nice", "well educated on the pros and c...
# 11           ["guilty", "mighty", "corrupt", "powerful"]
# 12                             ["proud", "accomplished"]
# 13                 ["confident", "committed", "helpful"]
# 14     ["included", "good", "happy", "happy to be inv...
# 15                    ["grateful", "happy", "satisfied"]
# 16     ["appreciated", "very pleasure of his work", "...
# 17                                  ["relieved", "good"]
# 18       ["grateful", "excited to see persony", "happy"]
# 19     ["happy that he saved a money", "satisfied wit...
# 20     ["excited", "happy", "happy to be getting star...
# 21                             ["sad", "worried", "sad"]
# 22     ["accomplished", "holy", "blessed", "forever g...
# 23                            ["satisfied", "satisfied"]
# 24                                         ["satisfied"]
# 25                            ["he will be good at it."]
# 26                   ["cooperative", "happy", "popular"]
# 27                                              ["safe"]
# 28                      ["grateful", "happy", "excited"]
# 29                        ["very happy", "accomplished"]
# ...                                                  ...
# 24282  ["relieved.", "tired", "proud of their work", ...
# 24283  ["fulfilled by writing the book", "relieved he...
# 24284  ["accomplished", "like their story is being to...
# 24285             ["satisfied", "friendly", "diligent."]
# 24286  ["accomplished", "accomplished", "happy", "in ...
# 24287                      ["accomplished", "satisfied"]
# 24288                                           ["fine"]
# 24289  ["content", "centered", "aware", "calmed", "re...
# 24290  ["expressive", "excited", "thankful", "grateful"]
# 24291  ["creative", "accomplished", "like he can be h...
# 24292        ["contented with his work", "accomplished"]
# 24293  ["artistic", "more educated", "more creative",...
# 24294  ["calm", "happy", "good that she accomplishes ...
# 24295  ["relieved", "expressive", "creative", "intell...
# 24296  ["tired", "anxious because it is due soon", "s...
# 24297  ["proud", "accomplished", "proud", "satisfied"...
# 24298                  ["responsible", "proud", "smart"]
# 24299  ["accomplished.", "like they are a credible so...
# 24300  ["glad to share their thoughts", "informative"...
# 24301            ["happy", "awesome", "less forgetful."]
# 24302                    ["funny", "superior and funny"]
# 24303  ["upset", "angry", "annoyed", "loud", "angry",...
# 24304  ["excited", "happy", "proud", "excited", "happ...
# 24305  ["helped", "horrified", "pathetic", "anxious f...
# 24306  ["frustrated", "annoyed", "angry", "upset", "f...
# 24307      ["excited", "excited", "content", "excited."]
# 24308     ["ashamed", "hurt", "in pain", "hurt", "sore"]
# 24309                 ["like they are restricting them"]
# 24310                                          ["happy"]
# 24311  ["regretful", "like he did the wrong thing, he...
#
#                                                    xWant  \
# 0      ["to escape from him", "to resign his job", "t...
# 1      ["Sell his land.", "Was just city.", "to start...
# 2      ["to go out", "to find other place", "find som...
# 3      ["human to be free", "not to feel pain", "to m...
# 4      ["to enforce the ruling", "memorialize the law...
# 5      ["to celebrate", "to write a paper", "to imple...
# 6      ["to live happily ever after", "to be happily ...
# 7      ["to tell others", "write a review", "to propo...
# 8      ["to feel satisfied", "to do it again", "Visit...
# 9      ["to buy more", "to eat more", "to take pictur...
# 10     ["not to waste any detail", "to make good use ...
# 11     ["harass employees", "tell others what to do u...
# 12     ["to attend  college", "to get a job", "get a ...
# 13     ["to assess the appointment", "to follow up wi...
# 14     ["go to engagement", "make a note", "to invite...
# 15     ["to start the new relationship", "to sign doc...
# 16     ["to relax", "to be happy", "to forgive him", ...
# 17     ["to forgive", "to move on", "to get apology",...
# 18     ["to honour person Y as a host", "to attend a ...
# 19     ["to pay money", "to look at the goods bought"...
# 20     ["to plan a wedding", "to marry", "for PersonY...
# 21     ["hire the replacment", "shake PersonYs hand",...
# 22     ["pray", "share their", "new faith", "to go to...
# 23     ["to be civil", "to make progress", "to try ou...
# 24     ["to go to the bank", "to save it", "to buy a ...
# 25     ["to create peace", "to make the country a bet...
# 26     ["recognition", "to slow down", "to get along ...
# 27     ["to repent for their sins", "to seek out a pr...
# 28     ["to go to the party", "to enjoy themself", "f...
# 29     ["to buy stuff for dorm room", "to get a job t...
# ...                                                  ...
# 24282  ["to turn it in", "to get a good grade", "Go t...
# 24283  ["proofread", "ask for feedback", "to share it...
# 24284  ["to be published", "fame", "fortune", "a best...
# 24285  ["to edit the letter", "to send out the letter...
# 24286  ["publish it", "read it", "to have their books...
# 24287  ["read his writing", "mail his writing", "mail...
# 24288  ["to put the letter in the mailbox", "to talk ...
# 24289  ["to hide their diary", "to read things from t...
# 24290  ["to put the letter in an envelope", "to addre...
# 24291  ["to play for friends", "to make a video for Y...
# 24292  ["to publish the poem", "to give the poem to s...
# 24293  ["to share their poetry online", "to try to ge...
# 24294  ["publish it", "send it to a publisher", "to r...
# 24295  ["to get someone to sing the songs", "to try s...
# 24296  ["publish writing", "proofread for errors", "t...
# 24297  ["Reading skill", "write skill", "to have the ...
# 24298  ["to hand in the essay", "to get a good grade"...
# 24299  ["give paper to teacher", "keep pen in compass...
# 24300  ["to send it to the publisher", "to ask for fe...
# 24301  ["to write a letter", "to pen down his thought...
# 24302  ["to run away", "to sell chain", "take the cha...
# 24303  ["to run away", "to get into a fight", "To not...
# 24304  ["to collect their prize", "to celebrate their...
# 24305  ["Run away", "Panic", "Fight", "to get helped"...
# 24306  ["to sigh.", "to yell out loud.", "to relax", ...
# 24307  ["to give them a present", "to feed them somet...
# 24308  ["visit doctor", "take pain pills", "to put a ...
# 24309  ["pay PersonY", "sign a contract", "to help Y"...
# 24310  ["to comment on it", "to admire them", "to imp...
# 24311  ["to sit down and rest", "to find out their ti...
#
#                             prefix split
# 0                 ["better", "go"]   dev
# 1       ["abandons", "altogether"]   trn
# 2       ["abandons", "altogether"]   trn
# 3      ["abolishes", "altogether"]   trn
# 4          ["abolishes", "states"]   trn
# 5      ["abolishes", "altogether"]   trn
# 6               ["get", "married"]   trn
# 7          ["absolutely", "loved"]   trn
# 8          ["absolutely", "loved"]   trn
# 9          ["absolutely", "loved"]   trn
# 10            ["absorbs", "every"]   trn
# 11             ["abuses", "power"]   tst
# 12          ["accepts", "diploma"]   dev
# 13      ["accepts", "appointment"]   trn
# 14       ["accepts", "invitation"]   dev
# 15            ["accepts", "offer"]   dev
# 16           ["accepts", "thanks"]   trn
# 17          ["accepts", "apology"]   tst
# 18       ["accepts", "invitation"]   dev
# 19            ["accepts", "offer"]   dev
# 20         ["accepts", "proposal"]   trn
# 21      ["accepts", "resignation"]   trn
# 22           ["accepts", "savior"]   trn
# 23         ["accepts", "exchange"]   dev
# 24          ["accepts", "payment"]   tst
# 25          ["accepts", "another"]   trn
# 26            ["accepts", "every"]   trn
# 27              ["accepts", "god"]   dev
# 28          ["accepts", "happily"]   dev
# 29          ["accepts", "college"]   trn
# ...                            ...   ...
# 24282          ["writes", "essay"]   trn
# 24283        ["writes", "another"]   trn
# 24284        ["writes", "another"]   trn
# 24285           ["writes", "back"]   trn
# 24286          ["writes", "books"]   trn
# 24287          ["writes", "every"]   trn
# 24288           ["writes", "home"]   trn
# 24289          ["writes", "diary"]   trn
# 24290        ["writes", "letters"]   dev
# 24291          ["writes", "music"]   tst
# 24292          ["writes", "poems"]   trn
# 24293         ["writes", "poetry"]   tst
# 24294          ["writes", "short"]   trn
# 24295          ["writes", "songs"]   trn
# 24296        ["writes", "stories"]   trn
# 24297           ["writes", "book"]   trn
# 24298          ["writes", "essay"]   trn
# 24299          ["writes", "paper"]   trn
# 24300          ["writes", "story"]   trn
# 24301           ["writes", "hand"]   trn
# 24302           ["yanks", "chain"]   trn
# 24303            ["yells", "back"]   trn
# 24304           ["yells", "bingo"]   trn
# 24305            ["yells", "help"]   trn
# 24306        ["yells", "silently"]   trn
# 24307        ["yells", "surprise"]   trn
# 24308            ["yelps", "pain"]   trn
# 24309         ["yields", "income"]   trn
# 24310    ["youngest", "president"]   trn
# 24311           ["zig", "shoulds"]   trn
#
# [24312 rows x 12 columns]
